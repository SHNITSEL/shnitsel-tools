# %%
import shnitsel as st
import xarray as xr
import numpy as np
from shnitsel.io.xyz.write import write_xyz

# %%
compound="A01"
dt = st.read(f"../test_data/shnitsel/{compound}/A01_ethene_0p50fs_dynamic.nc")

write_xyz(dt, "A01.xyz")
# Out:
# /scratch/khoellring/git/shnitsel-tools/shnitsel/units/conversion.py:235: FutureWarning: Deleting a single level of a MultiIndex is deprecated. Previously, this deleted all levels of a MultiIndex. Please also drop the following variables: {'frame'} to avoid an error in the future.
#   tmp = data.assign(new_vars)
# True

# %%
compound="A02"
dt = st.read(f"../test_data/shnitsel/{compound}/A02_propene_0p50fs_dynamic.nc")
write_xyz(dt, "A02.xyz")
# Out:
# /scratch/khoellring/git/shnitsel-tools/shnitsel/units/conversion.py:235: FutureWarning: Deleting a single level of a MultiIndex is deprecated. Previously, this deleted all levels of a MultiIndex. Please also drop the following variables: {'frame'} to avoid an error in the future.
#   tmp = data.assign(new_vars)
# True

# %%
compound="A03"
dt = st.read(f"../test_data/shnitsel/{compound}/A03_butene_0p50fs_dynamic.nc")
write_xyz(dt, "A03.xyz")
# Out:
# /scratch/khoellring/git/shnitsel-tools/shnitsel/units/conversion.py:235: FutureWarning: Deleting a single level of a MultiIndex is deprecated. Previously, this deleted all levels of a MultiIndex. Please also drop the following variables: {'frame'} to avoid an error in the future.
#   tmp = data.assign(new_vars)
# True
