# %%
import os
import shnitsel.dynamic as sh
# parse icond data
iconds_butene = sh.parse.sharc_icond.dirs_of_iconds(path='./test_data/sharc/iconds_butene')
# save the parsed data to h5netcdf file
savepath = os.path.join(os.getcwd(), 'test_data', 'sharc', 'iconds_butene.hdf5')
iconds_butene.reset_index('statecomb').to_netcdf(savepath, engine='h5netcdf')
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:root:no QM.log file found in ./test_data/sharc/iconds_butene/ICOND_00000.
#                 This is currently used to determine geometry.
#                 Eventually, user-inputs will be accepted as an alternative.
#                 See https://github.com/SHNITSEL/db-workflow/issues/3
# WARNING:root:no QM.log file found in ./test_data/sharc/iconds_butene/ICOND_00001.
#                 This is currently used to determine geometry.
#                 Eventually, user-inputs will be accepted as an alternative.
#                 See https://github.com/SHNITSEL/db-workflow/issues/3
# WARNING:root:no QM.log file found in ./test_data/sharc/iconds_butene/ICOND_00002.
#                 This is currently used to determine geometry.
#                 Eventually, user-inputs will be accepted as an alternative.
#                 See https://github.com/SHNITSEL/db-workflow/issues/3
# WARNING:root:no QM.log file found in ./test_data/sharc/iconds_butene/ICOND_00003.
#                 This is currently used to determine geometry.
#                 Eventually, user-inputs will be accepted as an alternative.
#                 See https://github.com/SHNITSEL/db-workflow/issues/3

# %%
import os
import shnitsel.dynamic as sh
# parse trajectory data from SHARC output files
traj_frames_butene = sh.parse.read_trajs('test_data/sharc/traj_butene', kind='sharc')
# parse trajectory data from Newton-X output files
traj_frames_chd = sh.parse.read_trajs('test_data/newtonx/', kind='nx')
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
import shnitsel.dynamic as sh
sh.open_frames('test_data/butene.nc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/git/shnitsel-tools/tutorials/test_data/butene.nc',), 'r', (('decode_vlen_strings', True), ('driver', None), ('invalid_netcdf', None)), '8d9010a9-34f7-4162-bc8e-214041f91ac0']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import shnitsel.dynamic as sh
# ----> 2 sh.open_frames('test_data/butene.nc')
#
# File /git/shnitsel-tools/shnitsel/dynamic/xrhelpers.py:93, in open_frames(path)
#      91 def open_frames(path):
#      92     try:
# ---> 93         frames = xr.open_dataset(path)
#      94     except ValueError as err:
#      95         if not os.path.exists(path):
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/api.py:670, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     658 decoders = _resolve_decoders_kwargs(
#     659     decode_cf,
#     660     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     666     decode_coords=decode_coords,
#     667 )
#     669 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 670 backend_ds = backend.open_dataset(
#     671     filename_or_obj,
#     672     drop_variables=drop_variables,
#     673     **decoders,
#     674     **kwargs,
#     675 )
#     676 ds = _dataset_from_backend_dataset(
#     677     backend_ds,
#     678     filename_or_obj,
#    (...)
#     688     **kwargs,
#     689 )
#     690 return ds
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:439, in H5netcdfBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     417 def open_dataset(
#     418     self,
#     419     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#     436     storage_options: dict[str, Any] | None = None,
#     437 ) -> Dataset:
#     438     filename_or_obj = _normalize_path(filename_or_obj)
# --> 439     store = H5NetCDFStore.open(
#     440         filename_or_obj,
#     441         format=format,
#     442         group=group,
#     443         lock=lock,
#     444         invalid_netcdf=invalid_netcdf,
#     445         phony_dims=phony_dims,
#     446         decode_vlen_strings=decode_vlen_strings,
#     447         driver=driver,
#     448         driver_kwds=driver_kwds,
#     449         storage_options=storage_options,
#     450     )
#     452     store_entrypoint = StoreBackendEntrypoint()
#     454     ds = store_entrypoint.open_dataset(
#     455         store,
#     456         mask_and_scale=mask_and_scale,
#    (...)
#     462         decode_timedelta=decode_timedelta,
#     463     )
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:195, in H5NetCDFStore.open(cls, filename, mode, format, group, lock, autoclose, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     192         lock = combine_locks([HDF5_LOCK, get_write_lock(filename)])
#     194 manager = CachingFileManager(h5netcdf.File, filename, mode=mode, kwargs=kwargs)
# --> 195 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:134, in H5NetCDFStore.__init__(self, manager, group, mode, lock, autoclose)
#     131 self.format = None
#     132 # todo: utilizing find_root_and_group seems a bit clunky
#     133 #  making filename available on h5netcdf.Group seems better
# --> 134 self._filename = find_root_and_group(self.ds)[0].filename
#     135 self.is_remote = is_remote_uri(self._filename)
#     136 self.lock = ensure_lock(lock)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:206, in H5NetCDFStore.ds(self)
#     204 @property
#     205 def ds(self):
# --> 206     return self._acquire()
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:198, in H5NetCDFStore._acquire(self, needs_lock)
#     197 def _acquire(self, needs_lock=True):
# --> 198     with self._manager.acquire_context(needs_lock) as root:
#     199         ds = _nc4_require_group(
#     200             root, self._group, self._mode, create_group=_h5netcdf_create_group
#     201         )
#     202     return ds
#
# File ~/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5netcdf/core.py:1522, in File.__init__(self, path, mode, invalid_netcdf, phony_dims, **kwargs)
#    1520         self._preexisting_file = os.path.exists(path) and mode != "w"
#    1521         self._h5py = h5py
# -> 1522         self._h5file = self._h5py.File(
#    1523             path, mode, track_order=track_order, **kwargs
#    1524         )
#    1525 elif isinstance(path, h5py.File):
#    1526     self._preexisting_file = mode in {"r", "r+", "a"}
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/git/shnitsel-tools/tutorials/test_data/butene.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
import shnitsel.dynamic as sh
# load trajectory data of A01
a01 = sh.open_frames('A01_ethene_dynamic.nc')
# create PCA plot over all trajectories with visualization of the
# four most important PCA-axis on the molecular structure
# C=C bond color highlighgting via KDE in PCA
sh.plot.biplot_kde(frames=a01, at1=0, at2=1, geo_filter=[[0,3],[5,20]], levels=10)
# C-H bond color highlighting via KDE in PCA
sh.plot.biplot_kde(frames=a01, at1=0, at2=2, geo_filter=[[0,3],[5,20]], levels=10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/git/shnitsel-tools/tutorials/A01_ethene_dynamic.nc',), 'r', (('decode_vlen_strings', True), ('driver', None), ('invalid_netcdf', None)), '59c79799-de71-46af-ad4b-7a090fb58130']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import shnitsel.dynamic as sh
#       2 # load trajectory data of A01
# ----> 3 a01 = sh.open_frames('A01_ethene_dynamic.nc')
#       4 # create PCA plot over all trajectories with visualization of the
#       5 # four most important PCA-axis on the molecular structure
#       6 # C=C bond color highlighgting via KDE in PCA
#       7 sh.plot.biplot_kde(frames=a01, at1=0, at2=1, geo_filter=[[0,3],[5,20]], levels=10)
#
# File /git/shnitsel-tools/shnitsel/dynamic/xrhelpers.py:93, in open_frames(path)
#      91 def open_frames(path):
#      92     try:
# ---> 93         frames = xr.open_dataset(path)
#      94     except ValueError as err:
#      95         if not os.path.exists(path):
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/api.py:670, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     658 decoders = _resolve_decoders_kwargs(
#     659     decode_cf,
#     660     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     666     decode_coords=decode_coords,
#     667 )
#     669 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 670 backend_ds = backend.open_dataset(
#     671     filename_or_obj,
#     672     drop_variables=drop_variables,
#     673     **decoders,
#     674     **kwargs,
#     675 )
#     676 ds = _dataset_from_backend_dataset(
#     677     backend_ds,
#     678     filename_or_obj,
#    (...)
#     688     **kwargs,
#     689 )
#     690 return ds
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:439, in H5netcdfBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     417 def open_dataset(
#     418     self,
#     419     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#     436     storage_options: dict[str, Any] | None = None,
#     437 ) -> Dataset:
#     438     filename_or_obj = _normalize_path(filename_or_obj)
# --> 439     store = H5NetCDFStore.open(
#     440         filename_or_obj,
#     441         format=format,
#     442         group=group,
#     443         lock=lock,
#     444         invalid_netcdf=invalid_netcdf,
#     445         phony_dims=phony_dims,
#     446         decode_vlen_strings=decode_vlen_strings,
#     447         driver=driver,
#     448         driver_kwds=driver_kwds,
#     449         storage_options=storage_options,
#     450     )
#     452     store_entrypoint = StoreBackendEntrypoint()
#     454     ds = store_entrypoint.open_dataset(
#     455         store,
#     456         mask_and_scale=mask_and_scale,
#    (...)
#     462         decode_timedelta=decode_timedelta,
#     463     )
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:195, in H5NetCDFStore.open(cls, filename, mode, format, group, lock, autoclose, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     192         lock = combine_locks([HDF5_LOCK, get_write_lock(filename)])
#     194 manager = CachingFileManager(h5netcdf.File, filename, mode=mode, kwargs=kwargs)
# --> 195 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:134, in H5NetCDFStore.__init__(self, manager, group, mode, lock, autoclose)
#     131 self.format = None
#     132 # todo: utilizing find_root_and_group seems a bit clunky
#     133 #  making filename available on h5netcdf.Group seems better
# --> 134 self._filename = find_root_and_group(self.ds)[0].filename
#     135 self.is_remote = is_remote_uri(self._filename)
#     136 self.lock = ensure_lock(lock)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:206, in H5NetCDFStore.ds(self)
#     204 @property
#     205 def ds(self):
# --> 206     return self._acquire()
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:198, in H5NetCDFStore._acquire(self, needs_lock)
#     197 def _acquire(self, needs_lock=True):
# --> 198     with self._manager.acquire_context(needs_lock) as root:
#     199         ds = _nc4_require_group(
#     200             root, self._group, self._mode, create_group=_h5netcdf_create_group
#     201         )
#     202     return ds
#
# File ~/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5netcdf/core.py:1522, in File.__init__(self, path, mode, invalid_netcdf, phony_dims, **kwargs)
#    1520         self._preexisting_file = os.path.exists(path) and mode != "w"
#    1521         self._h5py = h5py
# -> 1522         self._h5file = self._h5py.File(
#    1523             path, mode, track_order=track_order, **kwargs
#    1524         )
#    1525 elif isinstance(path, h5py.File):
#    1526     self._preexisting_file = mode in {"r", "r+", "a"}
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/git/shnitsel-tools/tutorials/A01_ethene_dynamic.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
import shnitsel.dynamic as sh
sheet = sh.plot.Datasheet(path='A01_ethene_dynamic.nc')
sheet.plot_per_state_histograms()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import shnitsel.dynamic as sh
# ----> 2 sheet = sh.plot.Datasheet(path='A01_ethene_dynamic.nc')
#       3 sheet.plot_per_state_histograms()
#
# AttributeError: module 'shnitsel.dynamic.plot' has no attribute 'Datasheet'

# %%
from shnitsel.dynamic.plot import Datasheet
sheet_a01 = Datasheet(path='A01_ethene_dynamic.nc')
sheet_i01 = Datasheet(path='I01_ch2nh2_dynamic.nc')
# inter-state histograms
sheet_a01.plot_nacs_histograms()
sheet_i01.plot_nacs_histograms()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from shnitsel.dynamic.plot import Datasheet
#       2 sheet_a01 = Datasheet(path='A01_ethene_dynamic.nc')
#       3 sheet_i01 = Datasheet(path='I01_ch2nh2_dynamic.nc')
#
# ImportError: cannot import name 'Datasheet' from 'shnitsel.dynamic.plot' (/git/shnitsel-tools/shnitsel/dynamic/plot/__init__.py)

# %%
import shnitsel.dynamic as sh
# load data
spectra_data = (sh.open_frames(path='A01_ethene_dynamic.nc')
.pipe(sh.get_inter_state)
.pipe(sh.assign_fosc)
.pipe(sh.spectra_all_times))
# plot spectra at different simulation times in one plot with a dahsed line that tracks the maximum
sh.plot.ski_plots(spectra_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/git/shnitsel-tools/tutorials/A01_ethene_dynamic.nc',), 'r', (('decode_vlen_strings', True), ('driver', None), ('invalid_netcdf', None)), '873d5838-2593-4d27-bff5-11fad57a5758']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import shnitsel.dynamic as sh
#       2 # load data
# ----> 3 spectra_data = (sh.open_frames(path='A01_ethene_dynamic.nc')
#       4 .pipe(sh.get_inter_state)
#       5 .pipe(sh.assign_fosc)
#       6 .pipe(sh.spectra_all_times))
#       7 # plot spectra at different simulation times in one plot with a dahsed line that tracks the maximum
#       8 sh.plot.ski_plots(spectra_data)
#
# File /git/shnitsel-tools/shnitsel/dynamic/xrhelpers.py:93, in open_frames(path)
#      91 def open_frames(path):
#      92     try:
# ---> 93         frames = xr.open_dataset(path)
#      94     except ValueError as err:
#      95         if not os.path.exists(path):
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/api.py:670, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     658 decoders = _resolve_decoders_kwargs(
#     659     decode_cf,
#     660     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     666     decode_coords=decode_coords,
#     667 )
#     669 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 670 backend_ds = backend.open_dataset(
#     671     filename_or_obj,
#     672     drop_variables=drop_variables,
#     673     **decoders,
#     674     **kwargs,
#     675 )
#     676 ds = _dataset_from_backend_dataset(
#     677     backend_ds,
#     678     filename_or_obj,
#    (...)
#     688     **kwargs,
#     689 )
#     690 return ds
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:439, in H5netcdfBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     417 def open_dataset(
#     418     self,
#     419     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#     436     storage_options: dict[str, Any] | None = None,
#     437 ) -> Dataset:
#     438     filename_or_obj = _normalize_path(filename_or_obj)
# --> 439     store = H5NetCDFStore.open(
#     440         filename_or_obj,
#     441         format=format,
#     442         group=group,
#     443         lock=lock,
#     444         invalid_netcdf=invalid_netcdf,
#     445         phony_dims=phony_dims,
#     446         decode_vlen_strings=decode_vlen_strings,
#     447         driver=driver,
#     448         driver_kwds=driver_kwds,
#     449         storage_options=storage_options,
#     450     )
#     452     store_entrypoint = StoreBackendEntrypoint()
#     454     ds = store_entrypoint.open_dataset(
#     455         store,
#     456         mask_and_scale=mask_and_scale,
#    (...)
#     462         decode_timedelta=decode_timedelta,
#     463     )
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:195, in H5NetCDFStore.open(cls, filename, mode, format, group, lock, autoclose, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     192         lock = combine_locks([HDF5_LOCK, get_write_lock(filename)])
#     194 manager = CachingFileManager(h5netcdf.File, filename, mode=mode, kwargs=kwargs)
# --> 195 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:134, in H5NetCDFStore.__init__(self, manager, group, mode, lock, autoclose)
#     131 self.format = None
#     132 # todo: utilizing find_root_and_group seems a bit clunky
#     133 #  making filename available on h5netcdf.Group seems better
# --> 134 self._filename = find_root_and_group(self.ds)[0].filename
#     135 self.is_remote = is_remote_uri(self._filename)
#     136 self.lock = ensure_lock(lock)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:206, in H5NetCDFStore.ds(self)
#     204 @property
#     205 def ds(self):
# --> 206     return self._acquire()
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:198, in H5NetCDFStore._acquire(self, needs_lock)
#     197 def _acquire(self, needs_lock=True):
# --> 198     with self._manager.acquire_context(needs_lock) as root:
#     199         ds = _nc4_require_group(
#     200             root, self._group, self._mode, create_group=_h5netcdf_create_group
#     201         )
#     202     return ds
#
# File ~/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5netcdf/core.py:1522, in File.__init__(self, path, mode, invalid_netcdf, phony_dims, **kwargs)
#    1520         self._preexisting_file = os.path.exists(path) and mode != "w"
#    1521         self._h5py = h5py
# -> 1522         self._h5file = self._h5py.File(
#    1523             path, mode, track_order=track_order, **kwargs
#    1524         )
#    1525 elif isinstance(path, h5py.File):
#    1526     self._preexisting_file = mode in {"r", "r+", "a"}
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/git/shnitsel-tools/tutorials/A01_ethene_dynamic.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
from shnitsel.dynamic.plot import Datasheet
# load data
sheet_a01 = Datasheet(path='A01_ethene_dynamic.nc')
sheet_i01 = Datasheet(path='I01_ch2nh2_dynamic.nc')
# time plots
sheet_a01.plot_timeplots()
sheet_i01.plot_timeplots()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/git/shnitsel-tools/tutorials/A01_ethene_dynamic.nc',), 'r', (('decode_vlen_strings', True), ('driver', None), ('invalid_netcdf', None)), '1ee82d11-8858-48e1-a228-6ad9705a80e8']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 from shnitsel.dynamic.plot import Datasheet
#       2 # load data
# ----> 3 sheet_a01 = Datasheet(path='A01_ethene_dynamic.nc')
#       4 sheet_i01 = Datasheet(path='I01_ch2nh2_dynamic.nc')
#       5 # time plots
#
# File /git/shnitsel-tools/shnitsel/dynamic/datasheet/oop.py:54, in Datasheet.__init__(self, path, frames, copy_data, spectra_times, col_state, col_inter)
#      52     self.frames = frames
#      53 elif path is not None:
# ---> 54     self.frames = xh.open_frames(path)
#      55 else:
#      56     warning("Neither path nor frames given, please set frames manually")
#
# File /git/shnitsel-tools/shnitsel/dynamic/xrhelpers.py:93, in open_frames(path)
#      91 def open_frames(path):
#      92     try:
# ---> 93         frames = xr.open_dataset(path)
#      94     except ValueError as err:
#      95         if not os.path.exists(path):
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/api.py:670, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     658 decoders = _resolve_decoders_kwargs(
#     659     decode_cf,
#     660     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     666     decode_coords=decode_coords,
#     667 )
#     669 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 670 backend_ds = backend.open_dataset(
#     671     filename_or_obj,
#     672     drop_variables=drop_variables,
#     673     **decoders,
#     674     **kwargs,
#     675 )
#     676 ds = _dataset_from_backend_dataset(
#     677     backend_ds,
#     678     filename_or_obj,
#    (...)
#     688     **kwargs,
#     689 )
#     690 return ds
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:439, in H5netcdfBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     417 def open_dataset(
#     418     self,
#     419     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#     436     storage_options: dict[str, Any] | None = None,
#     437 ) -> Dataset:
#     438     filename_or_obj = _normalize_path(filename_or_obj)
# --> 439     store = H5NetCDFStore.open(
#     440         filename_or_obj,
#     441         format=format,
#     442         group=group,
#     443         lock=lock,
#     444         invalid_netcdf=invalid_netcdf,
#     445         phony_dims=phony_dims,
#     446         decode_vlen_strings=decode_vlen_strings,
#     447         driver=driver,
#     448         driver_kwds=driver_kwds,
#     449         storage_options=storage_options,
#     450     )
#     452     store_entrypoint = StoreBackendEntrypoint()
#     454     ds = store_entrypoint.open_dataset(
#     455         store,
#     456         mask_and_scale=mask_and_scale,
#    (...)
#     462         decode_timedelta=decode_timedelta,
#     463     )
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:195, in H5NetCDFStore.open(cls, filename, mode, format, group, lock, autoclose, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     192         lock = combine_locks([HDF5_LOCK, get_write_lock(filename)])
#     194 manager = CachingFileManager(h5netcdf.File, filename, mode=mode, kwargs=kwargs)
# --> 195 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:134, in H5NetCDFStore.__init__(self, manager, group, mode, lock, autoclose)
#     131 self.format = None
#     132 # todo: utilizing find_root_and_group seems a bit clunky
#     133 #  making filename available on h5netcdf.Group seems better
# --> 134 self._filename = find_root_and_group(self.ds)[0].filename
#     135 self.is_remote = is_remote_uri(self._filename)
#     136 self.lock = ensure_lock(lock)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:206, in H5NetCDFStore.ds(self)
#     204 @property
#     205 def ds(self):
# --> 206     return self._acquire()
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:198, in H5NetCDFStore._acquire(self, needs_lock)
#     197 def _acquire(self, needs_lock=True):
# --> 198     with self._manager.acquire_context(needs_lock) as root:
#     199         ds = _nc4_require_group(
#     200             root, self._group, self._mode, create_group=_h5netcdf_create_group
#     201         )
#     202     return ds
#
# File ~/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5netcdf/core.py:1522, in File.__init__(self, path, mode, invalid_netcdf, phony_dims, **kwargs)
#    1520         self._preexisting_file = os.path.exists(path) and mode != "w"
#    1521         self._h5py = h5py
# -> 1522         self._h5file = self._h5py.File(
#    1523             path, mode, track_order=track_order, **kwargs
#    1524         )
#    1525 elif isinstance(path, h5py.File):
#    1526     self._preexisting_file = mode in {"r", "r+", "a"}
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/git/shnitsel-tools/tutorials/A01_ethene_dynamic.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
from shnitsel.dynamic.plot import Datasheet
# load data
sheet_a01 = Datasheet(path='A01_ethene_dynamic.nc')
# automatic generation of datasheet
sheet_a01.charge = 0
sheet_a01.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'h5netcdf.core.File'>, ('/git/shnitsel-tools/tutorials/A01_ethene_dynamic.nc',), 'r', (('decode_vlen_strings', True), ('driver', None), ('invalid_netcdf', None)), '6ca6baa3-38c1-48c6-9bf4-751705756bb8']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 from shnitsel.dynamic.plot import Datasheet
#       2 # load data
# ----> 3 sheet_a01 = Datasheet(path='A01_ethene_dynamic.nc')
#       4 # automatic generation of datasheet
#       5 sheet_a01.charge = 0
#
# File /git/shnitsel-tools/shnitsel/dynamic/datasheet/oop.py:54, in Datasheet.__init__(self, path, frames, copy_data, spectra_times, col_state, col_inter)
#      52     self.frames = frames
#      53 elif path is not None:
# ---> 54     self.frames = xh.open_frames(path)
#      55 else:
#      56     warning("Neither path nor frames given, please set frames manually")
#
# File /git/shnitsel-tools/shnitsel/dynamic/xrhelpers.py:93, in open_frames(path)
#      91 def open_frames(path):
#      92     try:
# ---> 93         frames = xr.open_dataset(path)
#      94     except ValueError as err:
#      95         if not os.path.exists(path):
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/api.py:670, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     658 decoders = _resolve_decoders_kwargs(
#     659     decode_cf,
#     660     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     666     decode_coords=decode_coords,
#     667 )
#     669 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 670 backend_ds = backend.open_dataset(
#     671     filename_or_obj,
#     672     drop_variables=drop_variables,
#     673     **decoders,
#     674     **kwargs,
#     675 )
#     676 ds = _dataset_from_backend_dataset(
#     677     backend_ds,
#     678     filename_or_obj,
#    (...)
#     688     **kwargs,
#     689 )
#     690 return ds
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:439, in H5netcdfBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, format, group, lock, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     417 def open_dataset(
#     418     self,
#     419     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#     436     storage_options: dict[str, Any] | None = None,
#     437 ) -> Dataset:
#     438     filename_or_obj = _normalize_path(filename_or_obj)
# --> 439     store = H5NetCDFStore.open(
#     440         filename_or_obj,
#     441         format=format,
#     442         group=group,
#     443         lock=lock,
#     444         invalid_netcdf=invalid_netcdf,
#     445         phony_dims=phony_dims,
#     446         decode_vlen_strings=decode_vlen_strings,
#     447         driver=driver,
#     448         driver_kwds=driver_kwds,
#     449         storage_options=storage_options,
#     450     )
#     452     store_entrypoint = StoreBackendEntrypoint()
#     454     ds = store_entrypoint.open_dataset(
#     455         store,
#     456         mask_and_scale=mask_and_scale,
#    (...)
#     462         decode_timedelta=decode_timedelta,
#     463     )
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:195, in H5NetCDFStore.open(cls, filename, mode, format, group, lock, autoclose, invalid_netcdf, phony_dims, decode_vlen_strings, driver, driver_kwds, storage_options)
#     192         lock = combine_locks([HDF5_LOCK, get_write_lock(filename)])
#     194 manager = CachingFileManager(h5netcdf.File, filename, mode=mode, kwargs=kwargs)
# --> 195 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:134, in H5NetCDFStore.__init__(self, manager, group, mode, lock, autoclose)
#     131 self.format = None
#     132 # todo: utilizing find_root_and_group seems a bit clunky
#     133 #  making filename available on h5netcdf.Group seems better
# --> 134 self._filename = find_root_and_group(self.ds)[0].filename
#     135 self.is_remote = is_remote_uri(self._filename)
#     136 self.lock = ensure_lock(lock)
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:206, in H5NetCDFStore.ds(self)
#     204 @property
#     205 def ds(self):
# --> 206     return self._acquire()
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/h5netcdf_.py:198, in H5NetCDFStore._acquire(self, needs_lock)
#     197 def _acquire(self, needs_lock=True):
# --> 198     with self._manager.acquire_context(needs_lock) as root:
#     199         ds = _nc4_require_group(
#     200             root, self._group, self._mode, create_group=_h5netcdf_create_group
#     201         )
#     202     return ds
#
# File ~/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5netcdf/core.py:1522, in File.__init__(self, path, mode, invalid_netcdf, phony_dims, **kwargs)
#    1520         self._preexisting_file = os.path.exists(path) and mode != "w"
#    1521         self._h5py = h5py
# -> 1522         self._h5file = self._h5py.File(
#    1523             path, mode, track_order=track_order, **kwargs
#    1524         )
#    1525 elif isinstance(path, h5py.File):
#    1526     self._preexisting_file = mode in {"r", "r+", "a"}
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File /git/shnitsel-tools/.venv/lib/python3.12/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '/git/shnitsel-tools/tutorials/A01_ethene_dynamic.nc', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
